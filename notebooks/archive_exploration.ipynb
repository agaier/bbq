# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from IPython.display import clear_output
from matplotlib import pyplot as plt
import numpy as np
np.set_printoptions(precision=2) 
np.set_printoptions(linewidth=160)
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w", 'bbox_inches': 'tight'}

import matplotlib
print(matplotlib.get_configdir())
# Out:
# /Users/gaiera/.matplotlib

# %%
from bbq.logging.vis import load_json, get_config_files, load_config, plot_stats, plot_pulse, plot_map

# %% [markdown]
# ### Load Sample Grid Archive

# %%
folder = 'sample_data/arm/CMA-ME/1'
 
p = load_config(get_config_files(folder))['archive']
fit = np.load(folder+'/archive/_fit.npy')
desc = np.load(folder+'/archive/_desc.npy')
meta = np.load(folder+'/archive/_meta.npy', allow_pickle=True)

# %% [markdown]
# ### View Objective in each bin

# %%
plot_map(fit, p, n_colors=8, bin_ticks=True, cmap='viridis')
# Out:
# <AxesSubplot:xlabel='X-Coord', ylabel='Y-Coord'>

# %% [markdown]
# ### View Individual Solution by Bin

# %%
from bbq.examples.planar_arm import visualize
from bbq.logging.vis import view_by_bin, view_best, view_solutions

fig,ax = plt.subplots(figsize=(9,4),dpi=100)    
plot_map(fit, p, bin_ticks=True, ax=ax)
view_by_bin((6,17), meta, visualize, ax)

# %% [markdown]
# ### View Best Solution

# %%
fig,ax = plt.subplots(figsize=(9,4),dpi=100)    
plot_map(fit, p, bin_ticks=True, ax=ax, n_colors=256)
view_best(fit, meta, visualize, ax)

# %% [markdown]
# ### View Representative solutions

# %%
bin_list = view_solutions(fit, meta, visualize, p, plot_per_side=4)

# %% [markdown]
# ### Customize bins to view

# %%
bin_list[2]=(12,13)
bin_list = view_solutions(fit, meta, visualize, p, plot_per_side=4, bin_list=bin_list)

# %% [markdown]
# ---

# %% [markdown]
# ### Load Sample CVT Archive

# %% [markdown]
# ### View Objective in each bin

# %% [markdown]
# ### View Representative Solutions
